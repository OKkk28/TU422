# %% [markdown]
# # AYTS 5001 - Lab 1 Template
# **Getting Started with Python**
#
# Fill in the code cells below as you work through the lab tasks.

# %% [markdown]
# ## 1. Environment Setup
# Run the cell below to confirm your environment works by printing out "Hello, world!":

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## 2. Variables and Data Types
# Create and print variables with different data types.

# %%
a = 1
b = 0.3
c = "hiii"
print(a, "type is", type(a))
print(b, "type is",type(b))
print(c,"type is", type(c))
# Out:
# 1 type is <class 'int'>
# 0.3 type is <class 'float'>
# hiii type is <class 'str'>

# %% [markdown]
# ## 3. Input and Output
# Use input() and print() to interact with the user.

# %%
name = input("what's your name")
print ("hi",name)
# Out:
# what's your namezida
# hi zida

# %% [markdown]
# ## 4. Expressions and Calculations
# Write a program that calculates the area and perimeter of a rectangle.

# %%
length = input("what is the length of that rectangle") 
width = input ("what is the width of that rectangle")
area = int(length) * int(width)
perimeter = 2 * (int(length) + int(width))
print(area)
print (perimeter)
# Out:
# what is the length of that rectangle2
# what is the width of that rectangle4
# 8
# 12

# %% [markdown]
# ## 5. Git Basics
# (Write down Git commands you used or plan to use.)

# %%
git remote add origin https://github.com/OKkk28/TU422.git
git branch -M main
git push -u origin main
# Out:
#   File "<ipython-input-31-3aac72e05d8c>", line 1
#     git remote add origin https://github.com/OKkk28/TU422.git
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 6. Extension Challenge: BMI Calculator
# (Optional) Write a program to calculate and print the BMI.

# %%
weight = input("what is your wight in kg")
hight = input("what is your hight in m")
BMI = int(weight) / (float(hight) ** 2)
print("your BMI is ",BMI)
# Out:
# what is your wight in kg100
# what is your hight in m1.8
# your BMI is  30.864197530864196
